# %%
import tensorflow as tf

# %%
# H(x) = Wx + b
# X and Y data
#x_train = [1,2,3]
#y_train = [1,2,3]
X = tf.placeholder(tf.float32, shape=[None])
Y = tf.placeholder(tf.float32, shape=[None])

W = tf.Variable(tf.random_normal([1]), name='weight')
b = tf.Variable(tf.random_normal([1]), name='bias')

# Our hypothesis Wx+b
hypothesis = X * W + b

# cost/Loss function
# cost = tf.reduce_mean(tf.square(hypothesis - y_train))
cost = tf.reduce_mean(tf.square(hypothesis - Y))

# Minimize
optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.01)
train = optimizer.minimize(cost)

# Launch the graph in a session.
sess = tf.Session()

# Initializes global variables in the graph.
sess.run(tf.global_variables_initializer())

# Fit the line
for step in range(2001):
    # sess.run(train)
    cost_val, W_val, b_val, _ = sess.run([cost, W, b, train], feed_dict={X: [1,2,3,4,5], Y: [2.1,3.1,4.1,5.1,6.1]})
    if step % 20 == 0:
        # print(step, sess.run(cost), sess.run(W), sess.run(b))
        print(step, cost_val, W_val, b_val)
        
print(sess.run(hypothesis, feed_dict={X:[5]}))
print(sess.run(hypothesis, feed_dict={X:[2.5]}))
print(sess.run(hypothesis, feed_dict={X:[1.5,3.5]}))
# Out:
# 0 3.4219074 [0.78193486] [0.36549094]
# 20 0.062798426 [1.1602877] [0.51443654]
# 40 0.054782607 [1.1514349] [0.553241]
# 60 0.0478421 [1.1415247] [0.5890508]
# 80 0.04178083 [1.1322562] [0.6225133]
# 100 0.036487497 [1.1235946] [0.6537844]
# 120 0.03186477 [1.1155002] [0.68300754]
# 140 0.027827775 [1.1079359] [0.71031666]
# 160 0.024302218 [1.1008672] [0.7358372]
# 180 0.021223288 [1.0942613] [0.7596866]
# 200 0.01853448 [1.0880882] [0.78197396]
# 220 0.016186263 [1.082319] [0.8028018]
# 240 0.014135582 [1.0769279] [0.8222656]
# 260 0.012344707 [1.0718898] [0.84045464]
# 280 0.010780714 [1.0671817] [0.85745263]
# 300 0.0094148945 [1.0627819] [0.87333715]
# 320 0.0082221 [1.0586703] [0.8881815]
# 340 0.0071804076 [1.0548279] [0.9020537]
# 360 0.0062707127 [1.0512373] [0.91501725]
# 380 0.0054762675 [1.0478816] [0.92713195]
# 400 0.0047824467 [1.0447458] [0.9384533]
# 420 0.0041765566 [1.0418154] [0.94903314]
# 440 0.0036474043 [1.0390768] [0.95892006]
# 460 0.0031853188 [1.0365177] [0.9681595]
# 480 0.0027817478 [1.0341262] [0.97679377]
# 500 0.0024293405 [1.0318911] [0.9848627]
# 520 0.0021215444 [1.0298024] [0.9924032]
# 540 0.001852772 [1.0278507] [0.9994498]
# 560 0.001618037 [1.0260268] [1.0060347]
# 580 0.0014130377 [1.0243223] [1.0121886]
# 600 0.0012340345 [1.0227295] [1.0179391]
# 620 0.0010776762 [1.021241] [1.0233135]
# 640 0.00094115624 [1.0198498] [1.0283355]
# 660 0.00082191563 [1.0185498] [1.033029]
# 680 0.00071779144 [1.017335] [1.0374149]
# 700 0.000626844 [1.0161997] [1.0415136]
# 720 0.00054742885 [1.0151389] [1.0453439]
# 740 0.0004780801 [1.0141474] [1.0489231]
# 760 0.0004175122 [1.0132209] [1.0522681]
# 780 0.00036461395 [1.012355] [1.0553943]
# 800 0.00031842507 [1.0115459] [1.0583154]
# 820 0.0002780832 [1.01079] [1.061045]
# 840 0.00024285151 [1.0100831] [1.0635964]
# 860 0.0002120824 [1.0094227] [1.0659806]
# 880 0.00018521496 [1.0088058] [1.0682086]
# 900 0.00016174503 [1.0082289] [1.0702909]
# 920 0.0001412539 [1.00769] [1.0722367]
# 940 0.00012335862 [1.0071863] [1.0740547]
# 960 0.000107729225 [1.0067158] [1.0757539]
# 980 9.4079805e-05 [1.0062759] [1.0773418]
# 1000 8.2161125e-05 [1.0058649] [1.0788258]
# 1020 7.175179e-05 [1.0054808] [1.0802126]
# 1040 6.26602e-05 [1.0051218] [1.0815085]
# 1060 5.472231e-05 [1.0047864] [1.0827194]
# 1080 4.7789606e-05 [1.004473] [1.0838512]
# 1100 4.1735497e-05 [1.0041801] [1.0849086]
# 1120 3.644864e-05 [1.0039062] [1.085897]
# 1140 3.1830066e-05 [1.0036504] [1.0868206]
# 1160 2.7796506e-05 [1.0034114] [1.0876838]
# 1180 2.4275443e-05 [1.0031879] [1.0884905]
# 1200 2.1200094e-05 [1.0029792] [1.089244]
# 1220 1.8513485e-05 [1.002784] [1.0899485]
# 1240 1.6169151e-05 [1.0026017] [1.0906068]
# 1260 1.4120084e-05 [1.0024314] [1.091222]
# 1280 1.233096e-05 [1.0022721] [1.0917968]
# 1300 1.076915e-05 [1.0021234] [1.092334]
# 1320 9.40484e-06 [1.0019842] [1.092836]
# 1340 8.213285e-06 [1.0018544] [1.093305]
# 1360 7.1732093e-06 [1.001733] [1.0937434]
# 1380 6.2644103e-06 [1.0016196] [1.0941532]
# 1400 5.4710736e-06 [1.0015135] [1.0945361]
# 1420 4.7777035e-06 [1.0014144] [1.0948937]
# 1440 4.1728586e-06 [1.0013217] [1.0952281]
# 1460 3.6445763e-06 [1.0012354] [1.0955404]
# 1480 3.1825864e-06 [1.0011544] [1.0958325]
# 1500 2.7794213e-06 [1.0010787] [1.0961055]
# 1520 2.4273945e-06 [1.0010082] [1.0963604]
# 1540 2.1204753e-06 [1.0009422] [1.0965985]
# 1560 1.8517579e-06 [1.0008806] [1.0968212]
# 1580 1.6173246e-06 [1.0008229] [1.0970293]
# 1600 1.4124969e-06 [1.000769] [1.0972236]
# 1620 1.2333242e-06 [1.0007187] [1.0974054]
# 1640 1.0773219e-06 [1.0006716] [1.0975753]
# 1660 9.4075585e-07 [1.0006276] [1.0977341]
# 1680 8.2153866e-07 [1.0005865] [1.0978824]
# 1700 7.175935e-07 [1.0005481] [1.098021]
# 1720 6.2678475e-07 [1.0005122] [1.0981506]
# 1740 5.4725405e-07 [1.0004786] [1.0982716]
# 1760 4.780646e-07 [1.0004474] [1.0983847]
# 1780 4.174799e-07 [1.0004182] [1.0984905]
# 1800 3.6465204e-07 [1.0003908] [1.0985893]
# 1820 3.1832542e-07 [1.0003651] [1.0986818]
# 1840 2.78115e-07 [1.0003412] [1.0987679]
# 1860 2.4286084e-07 [1.000319] [1.0988486]
# 1880 2.121943e-07 [1.000298] [1.0989239]
# 1900 1.8530156e-07 [1.0002787] [1.0989944]
# 1920 1.618691e-07 [1.0002604] [1.09906]
# 1940 1.4139746e-07 [1.0002434] [1.0991215]
# 1960 1.2351526e-07 [1.0002273] [1.0991789]
# 1980 1.07912776e-07 [1.0002127] [1.0992326]
# 2000 9.419591e-08 [1.0001986] [1.0992829]
# [6.1002755]
# [3.5997791]
# [2.5995808 4.599978 ]
